# %% [markdown]
# OBJECT DETECTION MODEL USING ***YOLOV8*
#
#
# ![image2.jpeg](data:image/jpeg;base64,...)
#
# PROJECT NAME-"**SEA CREATURE DETECTION**"

# %% [markdown]
# refrence images of training dataset

# %% [markdown]
# ![Screenshot (83).png](data:image/png;base64,...)

# %% [markdown]
# ![image1.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# this is one output  after working on model

# %% [markdown]
# **INTRODUCTION**

# %% [markdown]
# SPECIES NAME-
# {'anemone'
# 'barnacle'
# 'brittle-star'
# 'crab'
#  'crab_size'
#  'eel-grass'
#  'eel-pout-fish'
#   'flat-fish'
#   'laser'
# 'rock-fish'
#  'sea-pen'
#  'seastar'
#  'snail'}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# INSTALL ULTRALYTICS

# %% [markdown]
#  Ultralytics is a valuable tool for working with YOLO models, providing a seamless and efficient workflow for training, evaluating, and deploying object detection systems.

# %%
! pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.1/722.1 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 31.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 50.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 43.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 4.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %% [markdown]
# Model Initiation

# %%
model=YOLO('yolov8m.pt')
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 282MB/s]

# %%
model=YOLO('yolov8m.pt')
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 209MB/s]

# %% [markdown]
# Now we need to define a YAML file bcoz that file have location of our dataset

# %% [markdown]
# FINE TUNING OF THE MODEL

# %%
model.train(data='/content/drive/MyDrive/sea creature/Sea-Creatures-Detection.v17i.yolov8/data.yaml',epochs=5)
# Out:
# Ultralytics YOLOv8.1.31 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# this summary gives a save directory where best perfoming  model is saved
# save_dir=**runs/detect/train**
#
# under this dir , ther is weights file
# in this file have 2 model
#
# 1-best.pt(first best perfoming model)
#
# 2-last.pt (last(5th) best perfoming model)

# %% [markdown]
# Now here we infer the best performing model using its path

# %%
infer =YOLO('/content/runs/detect/train/weights/best.pt')

# %% [markdown]
# Here we use test images for prediction
#
# save=True (for saving the model)
#
# save_txt=True(foe sanig the text also)

# %%
infer.predict('/content/drive/MyDrive/sea creature/Sea-Creatures-Detection.v17i.yolov8/test/images',save=True,save_txt=True)
# Out:
# image 1/59 /content/drive/MyDrive/sea creature/Sea-Creatures-Detection.v17i.yolov8/test/images/frame10011_jpg.rf.86487dfae1d936f4c196475434088920.jpg: 640x640 4 anemones, 1 eel-pout-fish, 2 snails, 37.3ms
# image 2/59 /content/drive/MyDrive/sea creature/Sea-Creatures-Detection.v17i.yolov8/test/images/frame10062_jpg.rf.94e6e8575dcfd5a8738b577e98321c53.jpg: 640x640 2 anemones, 1 eel-pout-fish, 5 sea-pens, 3 snails, 37.4ms
# image 3/59 /content/drive/MyDrive/sea creature/Sea-Creatures-Detection.v17i.yolov8/test/images/frame10860_jpg.rf.5291122d9bb5e904298e12cd1a9d279e.jpg: 640x640 1 anemone, 1 crab, 3 eel-grasss, 1 sea-pen, 37.3ms
# image 4/59 /content/drive/MyDrive/sea creature/Sea-Creatures-Detection.v17i.yolov8/test/images/frame10940_jpg.rf.f12faaa21e4d20363909c956f1482538.jpg: 640x640 1 anemone, 1 brittle-star, 1 snail, 37.3ms
# ...

# %% [markdown]
# make prediction

# %%
infer.predict('/content/drive/MyDrive/sea creature/Sea-Creatures-Detection.v17i.yolov8/test/images',save=True,save_txt=True)
# Out:
# image 1/59 /content/drive/MyDrive/sea creature/Sea-Creatures-Detection.v17i.yolov8/test/images/frame10011_jpg.rf.86487dfae1d936f4c196475434088920.jpg: 640x640 4 anemones, 1 eel-pout-fish, 2 snails, 37.4ms
# image 2/59 /content/drive/MyDrive/sea creature/Sea-Creatures-Detection.v17i.yolov8/test/images/frame10062_jpg.rf.94e6e8575dcfd5a8738b577e98321c53.jpg: 640x640 2 anemones, 1 eel-pout-fish, 5 sea-pens, 3 snails, 37.3ms
# image 3/59 /content/drive/MyDrive/sea creature/Sea-Creatures-Detection.v17i.yolov8/test/images/frame10860_jpg.rf.5291122d9bb5e904298e12cd1a9d279e.jpg: 640x640 1 anemone, 1 crab, 3 eel-grasss, 1 sea-pen, 37.3ms
# image 4/59 /content/drive/MyDrive/sea creature/Sea-Creatures-Detection.v17i.yolov8/test/images/frame10940_jpg.rf.f12faaa21e4d20363909c956f1482538.jpg: 640x640 1 anemone, 1 brittle-star, 1 snail, 37.4ms
# ...

# %% [markdown]
# HENCE WE DETECT ALL SEA SPECIES IN GIVEN IN TEST DATASET
